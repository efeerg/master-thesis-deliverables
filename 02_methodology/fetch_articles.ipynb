# %% [markdown]
# # Literature Review: Article Fetching Process
#
# The notebook executes the literature review process to fetch the articles with the queries that has prepared and updated frequently during literature review process. The first part of the code concentrates on fetching articles from [Google Scholar](https://scholar.google.com) using [scholarly](https://pypi.org/project/scholarly/) library. The second part of the code prepares Excel files for personal assessment.

# %%
# Import libraries
import pandas as pd
from scholarly import scholarly

# %% [markdown]
# ## First Part: Fetching Articles
#
# In this part, the query performs the following operations:
# 1. Implemented `fetch_articles()` function gets the query, searches publications, and adds the outcomes to an array.
# 2. The search queries.
# 3. Execute the implemented function with the queries.
# 4. Turn the result into `DataFrame`.
# 5. Save the output as Excel file.
#
# To sum up, this process extracts the articles and prepares it for the second part.

# %%
# Function to fetch articles using the scholarly package
def fetch_articles(search_query):
    search_results = scholarly.search_pubs(search_query)
    articles = []
    for result in search_results:
        # Extract relevant information from each result
        bib_info = result.get('bib', {})
        article_info = {
            "title": bib_info.get('title'),
            "authors": bib_info.get('author'),
            "published_year": bib_info.get('pub_year'),
            "citations": result.get('num_citations', 0),
            "journal": bib_info.get('journal'),
            "volume": bib_info.get('volume'),
            "issue": bib_info.get('issue'),
            "pages": bib_info.get('pages'),
            "abstract": bib_info.get('abstract'),
            "doi": bib_info.get('doi'),
            "url": result.get('pub_url'),
            "publisher": bib_info.get('publisher'),
            "keywords": bib_info.get('keywords', []),
            "bib": bib_info
        }
        articles.append(article_info)
    return articles

# %% [markdown]
# ### The search queries

# %%
# Search queries

# OpenSSF Scorecard Search Query
# search_query = '"OpenSSF Scorecard" (history OR "theoretical background" OR "community involvement" OR purpose OR GitHub OR usage OR maintenance OR "maintenance score" OR reliability OR "security assessment" OR "best practices" OR impact OR application OR "case studies" OR "industry applications" OR benefits OR challenges)'

# Prediction Methods Search Query
search_query = '"univariate forecasting" (machine learning OR "deep learning") (prediction OR forecasting) (parameters OR features) ("time series" OR dataset) "supervised learning"'

# %%
# Fetch articles based on the search query
articles_data = fetch_articles(search_query)

# %% [markdown]
# ### Data manipulation and saving the output to Excel.

# %%
# Create a pandas DataFrame
df = pd.DataFrame(articles_data)
df.head()
# Out:
#                                                title  \
# 0  Univariate model for hour ahead multi-step sol...
# 1  Short-term daily univariate streamflow forecas...
# 2  Enhanced neural network-based univariate time-...
# 3  Forecasting from Physiological Time Series Thr...
# 4  Eeg forecasting with univariate and multivaria...
#
#                                             authors published_year  citations  \
# 0                                [P Gupta, R Singh]           2021         11
# 1                         [EB Wegayehu, FB Muluneh]           2022         34
# 2  [S Namasudra, S Dhamodharavadhani, R Rathipriya]           2024          5
# 3                                         [S Masum]           2019          3
# 4              [DK Thara, BG Premasudha, TV Murthy]           2022          3
#
#   journal volume issue pages  \
# 0    None   None  None  None
# 1    None   None  None  None
# 2    None   None  None  None
# 3    None   None  None  None
# 4    None   None  None  None
#
#                                             abstract   doi  \
# 0  Further, the problem is converted into a super...  None
# 1  As a result, machine learning models have beco...  None
# 2  accuracy because of the supervised learning me...  None
# 3  -independent medical time series data as stati...  None
# 4  using machine learning algorithms like support...  None
#
#                                                  url publisher keywords  \
# 0  https://ieeexplore.ieee.org/abstract/document/...      None       []
# 1  https://www.hindawi.com/journals/amete/2022/18...      None       []
# 2  https://www.liebertpub.com/doi/abs/10.1089/big...      None       []
# 3  https://www.researchgate.net/profile/Shamsul-M...      None       []
# 4  https://www.igi-global.com/article/eeg-forecas...      None       []
#
#                                                  bib
# 0  {'title': 'Univariate model for hour ahead mul...
# 1  {'title': 'Short-term daily univariate streamf...
# 2  {'title': 'Enhanced neural network-based univa...
# 3  {'title': 'Forecasting from Physiological Time...
# 4  {'title': 'Eeg forecasting with univariate and...

# %%
# Save the DataFrame to an Excel file
df.to_excel("../03_lit_review/scholarly_articles_prediction.xlsx", index=False, engine='openpyxl')

# %% [markdown]
# ## Second Part: Excel File Manipulation
#
# The second part of the code gets the Excel files obtained on the first part as inputs and performs the following operation to prepare these files in a readable format:

# %%
import pandas as pd
import openpyxl
from openpyxl import load_workbook

# Load the Excel file
df = pd.read_excel('../03_lit_review/scholarly_articles_prediction.xlsx')

# Add a new column named "Notes"
df['Notes'] = None

# Save the DataFrame to an Excel file
df.to_excel('../03_lit_review/scholarly_articles_prediction_x.xlsx', index=False, engine='openpyxl')

# Load the Excel file
wb = load_workbook('../03_lit_review/scholarly_articles_prediction_x.xlsx')
ws = wb.active

# Set the maximum length for each column and set the text wrap property to True
for column in ws.columns:
    max_length = 0
    column = [cell for cell in column]
    for cell in column:
        try: 
            if len(str(cell.value)) > max_length:
                max_length = len(cell.value)
        except:
            pass
    adjusted_width = (max_length if max_length < 50 else 50)
    ws.column_dimensions[column[0].column_letter].width = adjusted_width
    for cell in column:
        cell.alignment = openpyxl.styles.Alignment(wrap_text=True)

# Create a table style
tab = openpyxl.worksheet.table.Table(ref=ws.dimensions, displayName="Table1", tableStyleInfo=openpyxl.worksheet.table.TableStyleInfo(
    name="TableStyleMedium9", showFirstColumn=False,
    showLastColumn=False, showRowStripes=True, showColumnStripes=False))

# Add the table style to the worksheet
ws.add_table(tab)

# Save the workbook to the same Excel file
wb.save('../03_lit_review/scholarly_articles_prediction_final.xlsx')

# %%
def make_unique(df, column_name):
    counts = df.groupby(column_name).cumcount() + 1
    df[column_name] = df[column_name] + '_' + counts.astype(str)
    return df

# Function to join names from string
def join_names_from_string(names_string):
    # Remove the square brackets and split the string by commas
    names_string = names_string.strip("[]")
    # Split the string into a list of names and strip extra spaces and quotes
    names_list = [name.strip().strip("'") for name in names_string.split(',') if name.strip().strip("'")]
    # Join the names with " and "
    return ' and '.join(names_list)

# %%
data = pd.ExcelFile('../03_lit_review/scholarly_articles_prediction_final.xlsx')
data_df = pd.read_excel(data, 'Tabelle1')
data_df
# Out:
#                                                 title  \
# 0   Univariate model for hour ahead multi-step sol...
# 1   Short-term daily univariate streamflow forecas...
# 2   Forecasting from Physiological Time Series Thr...
# 3   A dynamic factor machine learning method for m...
# 4   Machine learning methods do have a place in un...
# ..                                                ...
# 65  Analysis factors affecting Egyptian inflation ...
# 66  Forecasting Retail Client Flow with LSTMs on I...
# 67  Employment forecasting using data from the Swe...
# 68  Charging Scheduling of Hybrid Energy Storage S...
# 69  Analysis and Forecasting of International Airp...
#
#                                               authors  published_year  \
# 0                              ['P Gupta', 'R Singh']          2021.0
# 1                       ['EB Wegayehu', 'FB Muluneh']          2022.0
# 2                                         ['S Masum']          2019.0
# 3                      ['G Bontempi', 'YA Le Borgne']          2017.0
# 4                 ['EM Riba', 'KM Malan', 'E Mudimu']             NaN
# ..                                                ...             ...
# 65                                  ['MF Abd El-Aal']          2023.0
# 66                ['P Gusmão', 'J Moreira', 'A Tomé']          2021.0
# 67                                     ['J Wikström']          2018.0
# 68                    ['G Erdogan', 'W Fekih Hassen']          2023.0
# 69  ['CH Yang', 'B Lee', 'PH Jou', 'YF Chung', 'YD...          2023.0
#
#     citations  journal  volume  issue  pages  \
# 0          11      NaN     NaN    NaN    NaN
# 1          34      NaN     NaN    NaN    NaN
# 2           3      NaN     NaN    NaN    NaN
# 3          11      NaN     NaN    NaN    NaN
# 4           0      NaN     NaN    NaN    NaN
# ..        ...      ...     ...    ...    ...
# 65          4      NaN     NaN    NaN    NaN
# 66          0      NaN     NaN    NaN    NaN
# 67          0      NaN     NaN    NaN    NaN
# 68          2      NaN     NaN    NaN    NaN
# 69          0      NaN     NaN    NaN    NaN
#
#                                              abstract  doi  ...  \
# 0   Further, the problem is converted into a super...  NaN  ...
# 1   As a result, machine learning models have beco...  NaN  ...
# 2   -independent medical time series data as stati...  NaN  ...
# 3   Multivariate time series forecasting involves ...  NaN  ...
# 4   of new and established univariate forecasting ...  NaN  ...
# ..                                                ...  ...  ...
# 65  algorithms outperforms univariate forecasting ...  NaN  ...
# 66  Because of this, the problem of forecasting is...  NaN  ...
# 67  statistical model used for univariate forecast...  NaN  ...
# 68  Two types of univariate forecasting were used ...  NaN  ...
# 69  Saayman concluded that univariate forecasting ...  NaN  ...
#
#                                                   bib  Technique  \
# 0   {'title': 'Univariate model for hour ahead mul...         ML
# 1   {'title': 'Short-term daily univariate streamf...         DL
# 2   {'title': 'Forecasting from Physiological Time...         ML
# 3   {'title': 'A dynamic factor machine learning m...         ML
# 4   {'title': 'Machine learning methods do have a ...         ML
# ..                                                ...        ...
# 65  {'title': 'Analysis factors affecting Egyptian...         ML
# 66  {'title': 'Forecasting Retail Client Flow with...         DL
# 67  {'title': 'Employment forecasting using data f...         DL
# 68  {'title': 'Charging Scheduling of Hybrid Energ...         DL
# 69  {'title': 'Analysis and Forecasting of Interna...         ML
#
#           Architecture Included Univariate?  \
# 0   Random Forest, SVM        Y           Y
# 1                 LSTM        Y           Y
# 2           Supervised        Y           Y
# 3                Other        Y           Y
# 4             Multiple        Y           Y
# ..                 ...      ...         ...
# 65            Multiple        Y           Y
# 66                LSTM        Y           Y
# 67           RNN, LSTM        Y           Y
# 68      LSTM, GRU, RNN        Y           Y
# 69            Multiple        Y           Y
#
#                                 Notes                Citation  \
# 0                                 NaN  ml_random_forest_svm_1
# 1                                 NaN               dl_lstm_1
# 2   Contains multiple usable methods.         ml_supervised_1
# 3     Multi-variate multi-step ahead.              ml_other_1
# 4     Univariate but multiple method.           ml_multiple_1
# ..                                ...                     ...
# 65                 Include the graph.           ml_multiple_6
# 66                 Include the graph.              dl_lstm_18
# 67                                NaN           dl_rnn_lstm_2
# 68                 Include the graph.       dl_lstm_gru_rnn_1
# 69                 Include the graph.           ml_multiple_7
#
#                                       author with and  \
# 0                                 P Gupta and R Singh
# 1                          EB Wegayehu and FB Muluneh
# 2                                             S Masum
# 3                         G Bontempi and YA Le Borgne
# 4                   EM Riba and KM Malan and E Mudimu
# ..                                                ...
# 65                                      MF Abd El-Aal
# 66                  P Gusmão and J Moreira and A Tomé
# 67                                         J Wikström
# 68                       G Erdogan and W Fekih Hassen
# 69  CH Yang and B Lee and PH Jou and YF Chung and ...
#
#                                    Format Cite
# 0   \protect\cite{ml_random_forest_svm_1}  NaN
# 1                \protect\cite{dl_lstm_1}  NaN
# 2          \protect\cite{ml_supervised_1}  NaN
# 3               \protect\cite{ml_other_1}  NaN
# 4            \protect\cite{ml_multiple_1}  NaN
# ..                                    ...  ...
# 65           \protect\cite{ml_multiple_6}  NaN
# 66              \protect\cite{dl_lstm_18}  NaN
# 67           \protect\cite{dl_rnn_lstm_2}  NaN
# 68       \protect\cite{dl_lstm_gru_rnn_1}  NaN
# 69           \protect\cite{ml_multiple_7}  NaN
#
# [70 rows x 23 columns]

# %%
data_df['Citation'] = data_df['Technique'].str.replace(', ', '_').str.lower() + '_' + data_df['Architecture'].str.replace(', ', '_').str.lower()
data_df['Citation'] = data_df['Citation'].str.replace(' ', '_')
data_df = make_unique(data_df, 'Citation')
data_df['author with and'] = data_df['authors'].apply(join_names_from_string)
data_df['Format'] = '\protect\cite{' + data_df['Citation'] + '}'
data_df['Cite'] = '@article{' + data_df['Citation'] + ',\n\t title = {' + data_df['title'] + '},\n\tauthor={' + data_df['author with and'] + '},\n\tyear={' + data_df['published_year'].astype(str).str[:4] + '},\n\tjournal={' + 'Undefined' + '},\n}'
data_df
# Out:
#                                                 title  \
# 0   Univariate model for hour ahead multi-step sol...
# 1   Short-term daily univariate streamflow forecas...
# 2   Forecasting from Physiological Time Series Thr...
# 3   A dynamic factor machine learning method for m...
# 4   Machine learning methods do have a place in un...
# ..                                                ...
# 65  Analysis factors affecting Egyptian inflation ...
# 66  Forecasting Retail Client Flow with LSTMs on I...
# 67  Employment forecasting using data from the Swe...
# 68  Charging Scheduling of Hybrid Energy Storage S...
# 69  Analysis and Forecasting of International Airp...
#
#                                               authors  published_year  \
# 0                              ['P Gupta', 'R Singh']          2021.0
# 1                       ['EB Wegayehu', 'FB Muluneh']          2022.0
# 2                                         ['S Masum']          2019.0
# 3                      ['G Bontempi', 'YA Le Borgne']          2017.0
# 4                 ['EM Riba', 'KM Malan', 'E Mudimu']             NaN
# ..                                                ...             ...
# 65                                  ['MF Abd El-Aal']          2023.0
# 66                ['P Gusmão', 'J Moreira', 'A Tomé']          2021.0
# 67                                     ['J Wikström']          2018.0
# 68                    ['G Erdogan', 'W Fekih Hassen']          2023.0
# 69  ['CH Yang', 'B Lee', 'PH Jou', 'YF Chung', 'YD...          2023.0
#
#     citations  journal  volume  issue  pages  \
# 0          11      NaN     NaN    NaN    NaN
# 1          34      NaN     NaN    NaN    NaN
# 2           3      NaN     NaN    NaN    NaN
# 3          11      NaN     NaN    NaN    NaN
# 4           0      NaN     NaN    NaN    NaN
# ..        ...      ...     ...    ...    ...
# 65          4      NaN     NaN    NaN    NaN
# 66          0      NaN     NaN    NaN    NaN
# 67          0      NaN     NaN    NaN    NaN
# 68          2      NaN     NaN    NaN    NaN
# 69          0      NaN     NaN    NaN    NaN
#
#                                              abstract  doi  ...  \
# 0   Further, the problem is converted into a super...  NaN  ...
# 1   As a result, machine learning models have beco...  NaN  ...
# 2   -independent medical time series data as stati...  NaN  ...
# 3   Multivariate time series forecasting involves ...  NaN  ...
# 4   of new and established univariate forecasting ...  NaN  ...
# ..                                                ...  ...  ...
# 65  algorithms outperforms univariate forecasting ...  NaN  ...
# 66  Because of this, the problem of forecasting is...  NaN  ...
# 67  statistical model used for univariate forecast...  NaN  ...
# 68  Two types of univariate forecasting were used ...  NaN  ...
# 69  Saayman concluded that univariate forecasting ...  NaN  ...
#
#                                                   bib  Technique  \
# 0   {'title': 'Univariate model for hour ahead mul...         ML
# 1   {'title': 'Short-term daily univariate streamf...         DL
# 2   {'title': 'Forecasting from Physiological Time...         ML
# 3   {'title': 'A dynamic factor machine learning m...         ML
# 4   {'title': 'Machine learning methods do have a ...         ML
# ..                                                ...        ...
# 65  {'title': 'Analysis factors affecting Egyptian...         ML
# 66  {'title': 'Forecasting Retail Client Flow with...         DL
# 67  {'title': 'Employment forecasting using data f...         DL
# 68  {'title': 'Charging Scheduling of Hybrid Energ...         DL
# 69  {'title': 'Analysis and Forecasting of Interna...         ML
#
#           Architecture Included Univariate?  \
# 0   Random Forest, SVM        Y           Y
# 1                 LSTM        Y           Y
# 2           Supervised        Y           Y
# 3                Other        Y           Y
# 4             Multiple        Y           Y
# ..                 ...      ...         ...
# 65            Multiple        Y           Y
# 66                LSTM        Y           Y
# 67           RNN, LSTM        Y           Y
# 68      LSTM, GRU, RNN        Y           Y
# 69            Multiple        Y           Y
#
#                                 Notes                Citation  \
# 0                                 NaN  ml_random_forest_svm_1
# 1                                 NaN               dl_lstm_1
# 2   Contains multiple usable methods.         ml_supervised_1
# 3     Multi-variate multi-step ahead.              ml_other_1
# 4     Univariate but multiple method.           ml_multiple_1
# ..                                ...                     ...
# 65                 Include the graph.           ml_multiple_6
# 66                 Include the graph.              dl_lstm_18
# 67                                NaN           dl_rnn_lstm_2
# 68                 Include the graph.       dl_lstm_gru_rnn_1
# 69                 Include the graph.           ml_multiple_7
#
#                                       author with and  \
# 0                                 P Gupta and R Singh
# 1                          EB Wegayehu and FB Muluneh
# 2                                             S Masum
# 3                         G Bontempi and YA Le Borgne
# 4                   EM Riba and KM Malan and E Mudimu
# ..                                                ...
# 65                                      MF Abd El-Aal
# 66                  P Gusmão and J Moreira and A Tomé
# 67                                         J Wikström
# 68                       G Erdogan and W Fekih Hassen
# 69  CH Yang and B Lee and PH Jou and YF Chung and ...
#
#                                    Format  \
# 0   \protect\cite{ml_random_forest_svm_1}
# 1                \protect\cite{dl_lstm_1}
# 2          \protect\cite{ml_supervised_1}
# 3               \protect\cite{ml_other_1}
# 4            \protect\cite{ml_multiple_1}
# ..                                    ...
# 65           \protect\cite{ml_multiple_6}
# 66              \protect\cite{dl_lstm_18}
# 67           \protect\cite{dl_rnn_lstm_2}
# 68       \protect\cite{dl_lstm_gru_rnn_1}
# 69           \protect\cite{ml_multiple_7}
#
#                                                  Cite
# 0   @article{ml_random_forest_svm_1,\n\t title = {...
# 1   @article{dl_lstm_1,\n\t title = {Short-term da...
# 2   @article{ml_supervised_1,\n\t title = {Forecas...
# 3   @article{ml_other_1,\n\t title = {A dynamic fa...
# 4   @article{ml_multiple_1,\n\t title = {Machine l...
# ..                                                ...
# 65  @article{ml_multiple_6,\n\t title = {Analysis ...
# 66  @article{dl_lstm_18,\n\t title = {Forecasting ...
# 67  @article{dl_rnn_lstm_2,\n\t title = {Employmen...
# 68  @article{dl_lstm_gru_rnn_1,\n\t title = {Charg...
# 69  @article{ml_multiple_7,\n\t title = {Analysis ...
#
# [70 rows x 23 columns]

# %%
data_df.to_excel('../03_lit_review/scholarly_articles_prediction_final.xlsx', sheet_name='Tabelle1', index=False)

# %%
data_df['Architecture'] = data_df['Architecture'].str.split(', ')
data_df_individual = data_df.explode('Architecture')
data_df_individual
# Out:
#                                                 title  \
# 0   Univariate model for hour ahead multi-step sol...
# 1   Short-term daily univariate streamflow forecas...
# 2   Forecasting from Physiological Time Series Thr...
# 3   A dynamic factor machine learning method for m...
# 4   Machine learning methods do have a place in un...
# ..                                                ...
# 65  Analysis factors affecting Egyptian inflation ...
# 66  Forecasting Retail Client Flow with LSTMs on I...
# 67  Employment forecasting using data from the Swe...
# 68  Charging Scheduling of Hybrid Energy Storage S...
# 69  Analysis and Forecasting of International Airp...
#
#                                               authors  published_year  \
# 0                              ['P Gupta', 'R Singh']          2021.0
# 1                       ['EB Wegayehu', 'FB Muluneh']          2022.0
# 2                                         ['S Masum']          2019.0
# 3                      ['G Bontempi', 'YA Le Borgne']          2017.0
# 4                 ['EM Riba', 'KM Malan', 'E Mudimu']             NaN
# ..                                                ...             ...
# 65                                  ['MF Abd El-Aal']          2023.0
# 66                ['P Gusmão', 'J Moreira', 'A Tomé']          2021.0
# 67                                     ['J Wikström']          2018.0
# 68                    ['G Erdogan', 'W Fekih Hassen']          2023.0
# 69  ['CH Yang', 'B Lee', 'PH Jou', 'YF Chung', 'YD...          2023.0
#
#     citations  journal  volume  issue  pages  \
# 0          11      NaN     NaN    NaN    NaN
# 1          34      NaN     NaN    NaN    NaN
# 2           3      NaN     NaN    NaN    NaN
# 3          11      NaN     NaN    NaN    NaN
# 4           0      NaN     NaN    NaN    NaN
# ..        ...      ...     ...    ...    ...
# 65          4      NaN     NaN    NaN    NaN
# 66          0      NaN     NaN    NaN    NaN
# 67          0      NaN     NaN    NaN    NaN
# 68          2      NaN     NaN    NaN    NaN
# 69          0      NaN     NaN    NaN    NaN
#
#                                              abstract  doi  ... keywords  \
# 0   Further, the problem is converted into a super...  NaN  ...       []
# 1   As a result, machine learning models have beco...  NaN  ...       []
# 2   -independent medical time series data as stati...  NaN  ...       []
# 3   Multivariate time series forecasting involves ...  NaN  ...       []
# 4   of new and established univariate forecasting ...  NaN  ...       []
# ..                                                ...  ...  ...      ...
# 65  algorithms outperforms univariate forecasting ...  NaN  ...       []
# 66  Because of this, the problem of forecasting is...  NaN  ...       []
# 67  statistical model used for univariate forecast...  NaN  ...       []
# 68  Two types of univariate forecasting were used ...  NaN  ...       []
# 69  Saayman concluded that univariate forecasting ...  NaN  ...       []
#
#                                                   bib Technique Architecture  \
# 0   {'title': 'Univariate model for hour ahead mul...        ML          NaN
# 1   {'title': 'Short-term daily univariate streamf...        DL          NaN
# 2   {'title': 'Forecasting from Physiological Time...        ML          NaN
# 3   {'title': 'A dynamic factor machine learning m...        ML          NaN
# 4   {'title': 'Machine learning methods do have a ...        ML          NaN
# ..                                                ...       ...          ...
# 65  {'title': 'Analysis factors affecting Egyptian...        ML          NaN
# 66  {'title': 'Forecasting Retail Client Flow with...        DL          NaN
# 67  {'title': 'Employment forecasting using data f...        DL          NaN
# 68  {'title': 'Charging Scheduling of Hybrid Energ...        DL          NaN
# 69  {'title': 'Analysis and Forecasting of Interna...        ML          NaN
#
#    Included  Univariate?                              Notes  \
# 0         Y            Y                                NaN
# 1         Y            Y                                NaN
# 2         Y            Y  Contains multiple usable methods.
# 3         Y            Y    Multi-variate multi-step ahead.
# 4         Y            Y    Univariate but multiple method.
# ..      ...          ...                                ...
# 65        Y            Y                 Include the graph.
# 66        Y            Y                 Include the graph.
# 67        Y            Y                                NaN
# 68        Y            Y                 Include the graph.
# 69        Y            Y                 Include the graph.
#
#                   Citation                                 Format  \
# 0   ml_random forest_svm_1  \protect\cite{ml_random forest_svm_1}
# 1                dl_lstm_1               \protect\cite{dl_lstm_1}
# 2          ml_supervised_1         \protect\cite{ml_supervised_1}
# 3               ml_other_1              \protect\cite{ml_other_1}
# 4            ml_multiple_1           \protect\cite{ml_multiple_1}
# ..                     ...                                    ...
# 65           ml_multiple_6           \protect\cite{ml_multiple_6}
# 66              dl_lstm_18              \protect\cite{dl_lstm_18}
# 67           dl_rnn_lstm_2           \protect\cite{dl_rnn_lstm_2}
# 68       dl_lstm_gru_rnn_1       \protect\cite{dl_lstm_gru_rnn_1}
# 69           ml_multiple_7           \protect\cite{ml_multiple_7}
#
#                                                  Cite
# 0   @article{ml_random forest_svm_1, title = {Univ...
# 1   @article{dl_lstm_1, title = {Short-term daily ...
# 2   @article{ml_supervised_1, title = {Forecasting...
# 3   @article{ml_other_1, title = {A dynamic factor...
# 4   @article{ml_multiple_1, title = {Machine learn...
# ..                                                ...
# 65  @article{ml_multiple_6, title = {Analysis fact...
# 66  @article{dl_lstm_18, title = {Forecasting Reta...
# 67  @article{dl_rnn_lstm_2, title = {Employment fo...
# 68  @article{dl_lstm_gru_rnn_1, title = {Charging ...
# 69  @article{ml_multiple_7, title = {Analysis and ...
#
# [70 rows x 22 columns]

# %%
# Group the individual entries
data_df_grouped = data_df_individual.groupby(['Technique', 'Architecture']).size().reset_index(name='count')
data_df_grouped
# Out:
#    Technique        Architecture  count
# 0          -                   -      1
# 1         DL                 CNN      2
# 2         DL                 GRU      4
# 3         DL                LSTM     26
# 4         DL                 MLP      1
# 5         DL            Multiple      4
# 6         DL               Other      8
# 7         DL                 RNN      7
# 8         DL                 RNU      1
# 9         DL                 TCL      1
# 10        DL                 VAE      1
# 11        ML  Federated Learning      1
# 12        ML            Multiple      7
# 13        ML               Other      3
# 14        ML       Random Forest      2
# 15        ML                 SVM      2
# 16        ML                 SVR      2
# 17        ML          Supervised      1
# 18        ML                k-NN      1
# 19   ML, DL                 LSTM      2
# 20   ML, DL             Multiple      6
# 21   ML, DL                  SVR      1
# 22   ML, DL              XGBoost      1

# %%
data_df_individual
# Out:
#                                                 title  \
# 0   Univariate model for hour ahead multi-step sol...
# 0   Univariate model for hour ahead multi-step sol...
# 1   Short-term daily univariate streamflow forecas...
# 2   Forecasting from Physiological Time Series Thr...
# 3   A dynamic factor machine learning method for m...
# ..                                                ...
# 67  Employment forecasting using data from the Swe...
# 68  Charging Scheduling of Hybrid Energy Storage S...
# 68  Charging Scheduling of Hybrid Energy Storage S...
# 68  Charging Scheduling of Hybrid Energy Storage S...
# 69  Analysis and Forecasting of International Airp...
#
#                                               authors  published_year  \
# 0                              ['P Gupta', 'R Singh']          2021.0
# 0                              ['P Gupta', 'R Singh']          2021.0
# 1                       ['EB Wegayehu', 'FB Muluneh']          2022.0
# 2                                         ['S Masum']          2019.0
# 3                      ['G Bontempi', 'YA Le Borgne']          2017.0
# ..                                                ...             ...
# 67                                     ['J Wikström']          2018.0
# 68                    ['G Erdogan', 'W Fekih Hassen']          2023.0
# 68                    ['G Erdogan', 'W Fekih Hassen']          2023.0
# 68                    ['G Erdogan', 'W Fekih Hassen']          2023.0
# 69  ['CH Yang', 'B Lee', 'PH Jou', 'YF Chung', 'YD...          2023.0
#
#     citations  journal  volume  issue  pages  \
# 0          11      NaN     NaN    NaN    NaN
# 0          11      NaN     NaN    NaN    NaN
# 1          34      NaN     NaN    NaN    NaN
# 2           3      NaN     NaN    NaN    NaN
# 3          11      NaN     NaN    NaN    NaN
# ..        ...      ...     ...    ...    ...
# 67          0      NaN     NaN    NaN    NaN
# 68          2      NaN     NaN    NaN    NaN
# 68          2      NaN     NaN    NaN    NaN
# 68          2      NaN     NaN    NaN    NaN
# 69          0      NaN     NaN    NaN    NaN
#
#                                              abstract  doi  \
# 0   Further, the problem is converted into a super...  NaN
# 0   Further, the problem is converted into a super...  NaN
# 1   As a result, machine learning models have beco...  NaN
# 2   -independent medical time series data as stati...  NaN
# 3   Multivariate time series forecasting involves ...  NaN
# ..                                                ...  ...
# 67  statistical model used for univariate forecast...  NaN
# 68  Two types of univariate forecasting were used ...  NaN
# 68  Two types of univariate forecasting were used ...  NaN
# 68  Two types of univariate forecasting were used ...  NaN
# 69  Saayman concluded that univariate forecasting ...  NaN
#
#                                                   url  publisher keywords  \
# 0   https://ieeexplore.ieee.org/abstract/document/...        NaN       []
# 0   https://ieeexplore.ieee.org/abstract/document/...        NaN       []
# 1   https://www.hindawi.com/journals/amete/2022/18...        NaN       []
# 2   https://www.researchgate.net/profile/Shamsul-M...        NaN       []
# 3   https://ieeexplore.ieee.org/abstract/document/...        NaN       []
# ..                                                ...        ...      ...
# 67  https://www.diva-portal.org/smash/record.jsf?p...        NaN       []
# 68          https://www.mdpi.com/1996-1073/16/18/6656        NaN       []
# 68          https://www.mdpi.com/1996-1073/16/18/6656        NaN       []
# 68          https://www.mdpi.com/1996-1073/16/18/6656        NaN       []
# 69           https://www.mdpi.com/2227-7390/11/6/1483        NaN       []
#
#                                                   bib Technique  \
# 0   {'title': 'Univariate model for hour ahead mul...        ML
# 0   {'title': 'Univariate model for hour ahead mul...        ML
# 1   {'title': 'Short-term daily univariate streamf...        DL
# 2   {'title': 'Forecasting from Physiological Time...        ML
# 3   {'title': 'A dynamic factor machine learning m...        ML
# ..                                                ...       ...
# 67  {'title': 'Employment forecasting using data f...        DL
# 68  {'title': 'Charging Scheduling of Hybrid Energ...        DL
# 68  {'title': 'Charging Scheduling of Hybrid Energ...        DL
# 68  {'title': 'Charging Scheduling of Hybrid Energ...        DL
# 69  {'title': 'Analysis and Forecasting of Interna...        ML
#
#      Architecture Included Univariate?                              Notes
# 0   Random Forest        Y           Y                                NaN
# 0             SVM        Y           Y                                NaN
# 1            LSTM        Y           Y                                NaN
# 2      Supervised        Y           Y  Contains multiple usable methods.
# 3           Other        Y           Y    Multi-variate multi-step ahead.
# ..            ...      ...         ...                                ...
# 67           LSTM        Y           Y                                NaN
# 68           LSTM        Y           Y                 Include the graph.
# 68            GRU        Y           Y                 Include the graph.
# 68            RNN        Y           Y                 Include the graph.
# 69       Multiple        Y           Y                 Include the graph.
#
# [85 rows x 19 columns]
